# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# dataset

# %%
np.random.seed(42)

X = np.random.rand(50, 1) * 100  

Y = 3.5 * X + np.random.randn(50, 1) * 20

# %%
X = X.flatten()
Y = Y.flatten()

# %% [markdown]
# Hyperparametrs

# %%
learning_rate = 0.0001
epochs = 1000

# %% [markdown]
# Implementation

# %%
m = 0     # slope
c = 0     # intercept

N = len(X)

# Gradient Descent
for i in range(epochs):
    y_pred = m * X + c

    # Compute gradients
    dm = (-2/N) * np.sum(X * (Y - y_pred))
    dc = (-2/N) * np.sum(Y - y_pred)

    # Update parameters
    m = m - learning_rate * dm
    c = c - learning_rate * dc

print("\nFinal Slope (m):", m)
print("Final Intercept (c):", c)
# Out:
# Final Slope (m): 3.483474226701688
# Final Intercept (c): 0.16171624211801736

# %% [markdown]
# Plot

# %%
plt.scatter(X, Y, label="Data Points")
plt.plot(X, m*X + c, color='red', label="Regression Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
